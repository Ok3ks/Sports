# %%
# !pip install snakeviz
# Out:
# ...
#      |████████████████████████████████| 283 kB 1.4 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.1.1; however, version 24.0 is available.
# You should consider upgrading via the '/Users/max/Desktop/Sports/env/bin/python3 -m pip install --upgrade pip' command.

# %%
import pstats

p = pstats.Stats("report.stats")
p.sort_stats("cumulative")

# %%
p.print_stats()
# Out:
# Thu Feb  8 17:33:18 2024    report.stats
#
#          756373 function calls (735347 primitive calls) in 1.895 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    1008/1    0.015    0.000    1.897    1.897 {built-in method builtins.exec}
#         1    0.000    0.000    1.897    1.897 src/report.py:1(<module>)
#     878/1    0.003    0.000    1.689    1.689 <frozen importlib._bootstrap>:986(_find_and_load)
#     877/1    0.002    0.000    1.689    1.689 <frozen importlib._bootstrap>:956(_find_and_load_unlocked)
#     833/2    0.003    0.000    1.689    0.844 <frozen importlib._bootstrap>:650(_load_unlocked)
#     725/2    0.002    0.000    1.689    0.844 <frozen importlib._bootstrap_external>:842(exec_module)
#    1134/2    0.000    0.000    1.689    0.844 <frozen importlib._bootstrap>:211(_call_with_frames_removed)
#         1    0.000    0.000    1.688    1.688 /Users/max/Desktop/Sports/src/utils.py:1(<module>)
# ...
